# %%
const str1 = "Hello";
const str2 = "I am";
const str3 = "Aadi";

console.log(`Length of str1: ${str1.length}`);
console.log(`Length of str2: ${str2.length}`);
console.log(`Length of str3: ${str3.length}`);

console.log(`str1 starts with '${str1[0]}' and ends with '${str1[str1.length - 1]}'`);
console.log(`str2 starts with '${str2[0]}' and ends with '${str2[str2.length - 1]}'`);
console.log(`str3 starts with '${str3[0]}' and ends with '${str3[str3.length - 1]}'`);


console.log(`${str1} ${str2} ${str3}`);
