# %% [markdown]
# ---
# layout: post
# title: N@TM Blog
# description: My experience at N@TM
# permalink: /NATMBLOG/
# comments: true
# ---

# %% [markdown]
# ## Night at The Museum!
# I attended Night at The Museum where I collaborated with peers from my CSSE Period 1 Class, and we presented our game, called Murder Mystery.
#
# Our team
#
# Image 5
# My Experience
# It was really interesting to be in a room of many innovative students who are also interested in computer science. I was able to look at several different projects from CSP and CSA classes.
#
# We were able to present the different levels of our game of Murder Mystery to many students and parents
#
# Image 5 Image 5
# Projects I saw at NATM
# I was able to talk to many different CSP and CSA groups, and viewed their cool, interactive projects which involved frontend, backend, and features like API!
#
# Below are some of them that I found interesting.
#
# This interactive poll asks someone which AI they find most helpful, and I learned that the coders used special API and database to keep count of the votes Flag
# This interactive poll asks someone which AI they find most helpful, and I learned that the coders used special API and database to keep count of the votes
#
# Project 1
#
# This website is a trip planner and seems like a gamified way to plan a nice vacation! I learned that the coders also used API to list landmarks, shopping, and even weather Flag
# This website is a trip planner and seems like a gamified way to plan a nice vacation! I learned that the coders also used API to list landmarks, shopping, and even weather
#
# Project 2
#
# This platform is called Hunger Heroes and acts as a bridge between donors and receivers. I learned that the coders used backend database to manage user accounts and API for maps! Flag
# This platform is called Hunger Heroes and acts as a bridge between donors and receivers. I learned that the coders used backend database to manage user accounts and API for maps!
